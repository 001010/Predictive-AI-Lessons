# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print("="*60)
print(" WHY WE NEED CATEGORICAL ENCODING")
print("="*60)

# Create sample data with categories
data = pd.DataFrame({
    'Customer': ['John', 'Jane', 'Bob', 'Alice', 'Charlie'],
    'Product': ['Laptop', 'Phone', 'Tablet', 'Laptop', 'Phone'],
    'Size': ['Small', 'Medium', 'Large', 'Medium', 'Small'],
    'Color': ['Red', 'Blue', 'Green', 'Red', 'Blue'],
    'Price': [1000, 800, 600, 1100, 850]
})

print("📊 Original Data:")
print(data)

# Try to use in ML (will fail!)
print("\n❌ Problem:")
print("   Machine learning algorithms need NUMBERS, not text")
print("   We need to convert 'Laptop' → 1, 'Phone' → 2, etc.")
print("\n   But there are TWO ways to do this...")
# Out:
# ============================================================
#  WHY WE NEED CATEGORICAL ENCODING
# ============================================================
# 📊 Original Data:
#   Customer Product    Size  Color  Price
# 0     John  Laptop   Small    Red   1000
# 1     Jane   Phone  Medium   Blue    800
# 2      Bob  Tablet   Large  Green    600
# 3    Alice  Laptop  Medium    Red   1100
# 4  Charlie   Phone   Small   Blue    850
#
# ❌ Problem:
#    Machine learning algorithms need NUMBERS, not text
#    We need to convert 'Laptop' → 1, 'Phone' → 2, etc.
#
#    But there are TWO ways to do this...

# %%
from sklearn.preprocessing import LabelEncoder

print("\n" + "="*60)
print(" LABEL ENCODING (For Ordinal Data)")
print("="*60)

# Example: T-shirt sizes have natural order
sizes = pd.DataFrame({
    'Size': ['Small', 'Medium', 'Large', 'Medium', 'Small', 'XL', 'Small', 'Large']
})

print("📊 Original Sizes:")
print(sizes['Size'].value_counts())

# Apply Label Encoding
le = LabelEncoder()
sizes['Size_Encoded'] = le.fit_transform(sizes['Size'])

print("\n📊 After Label Encoding:")
print(sizes)
print(f"\nMapping: {dict(zip(le.classes_, le.transform(le.classes_)))}")

print("\n✓ WHEN TO USE:")
print("   • Education: High School < Bachelor < Master < PhD")
print("   • T-Shirt Size: XS < S < M < L < XL")
print("   • Rating: Poor < Fair < Good < Excellent")
print("   • Priority: Low < Medium < High")

print("\n❌ WHEN NOT TO USE:")
print("   • Colors: Red, Blue, Green (no order)")
print("   • Cities: NYC, LA, Chicago (no order)")
print("   • Product Categories: Laptop, Phone, Tablet (no order)")

# Create proper ordinal encoding with order
from sklearn.preprocessing import OrdinalEncoder

size_order = [['Small', 'Medium', 'Large', 'XL']]
ordinal_encoder = OrdinalEncoder(categories=size_order)
sizes['Size_Ordinal'] = ordinal_encoder.fit_transform(sizes[['Size']])

print("\n📊 Proper Ordinal Encoding:")
print(sizes)
print("   Small=0, Medium=1, Large=2, XL=3 ✓ (Maintains order)")
# Out:
# ============================================================
#  LABEL ENCODING (For Ordinal Data)
# ============================================================
# 📊 Original Sizes:
# Size
# Small     3
# Medium    2
# Large     2
# XL        1
# Name: count, dtype: int64
#
# 📊 After Label Encoding:
#      Size  Size_Encoded
# 0   Small             2
# 1  Medium             1
# 2   Large             0
# 3  Medium             1
# 4   Small             2
# 5      XL             3
# 6   Small             2
# 7   Large             0
#
# Mapping: {'Large': np.int64(0), 'Medium': np.int64(1), 'Small': np.int64(2), 'XL': np.int64(3)}
#
# ✓ WHEN TO USE:
#    • Education: High School < Bachelor < Master < PhD
#    • T-Shirt Size: XS < S < M < L < XL
#    • Rating: Poor < Fair < Good < Excellent
#    • Priority: Low < Medium < High
#
# ❌ WHEN NOT TO USE:
#    • Colors: Red, Blue, Green (no order)
#    • Cities: NYC, LA, Chicago (no order)
#    • Product Categories: Laptop, Phone, Tablet (no order)
#
# 📊 Proper Ordinal Encoding:
#      Size  Size_Encoded  Size_Ordinal
# 0   Small             2           0.0
# 1  Medium             1           1.0
# 2   Large             0           2.0
# 3  Medium             1           1.0
# 4   Small             2           0.0
# 5      XL             3           3.0
# 6   Small             2           0.0
# 7   Large             0           2.0
#    Small=0, Medium=1, Large=2, XL=3 ✓ (Maintains order)

# %%
print("\n" + "="*60)
print(" ONE-HOT ENCODING (For Nominal Data)")
print("="*60)

# Example: Product categories (no natural order)
products = pd.DataFrame({
    'Product': ['Laptop', 'Phone', 'Tablet', 'Laptop', 'Phone', 'Watch', 'Tablet'],
    'Price': [1000, 800, 600, 1100, 850, 300, 650]
})

print("📊 Original Data:")
print(products)

# Apply One-Hot Encoding
products_encoded = pd.get_dummies(products, columns=['Product'], prefix='Product')

print("\n📊 After One-Hot Encoding:")
print(products_encoded)

print("\n💡 HOW IT WORKS:")
print("   • Creates a NEW COLUMN for each category")
print("   • Uses 1 if that's the category, 0 otherwise")
print("   • 'Laptop' becomes: Product_Laptop=1, Product_Phone=0, Product_Tablet=0")

print("\n✓ ADVANTAGES:")
print("   • No false ordering (Laptop ≠ 'better' than Phone)")
print("   • ML algorithms treat each category independently")

print("\n⚠️  DISADVANTAGES:")
print("   • Creates many columns if many categories")
print("   • Can lead to 'curse of dimensionality'")

# Alternative: Drop first column to avoid multicollinearity
products_encoded_drop = pd.get_dummies(products, columns=['Product'], prefix='Product', drop_first=True)

print("\n📊 One-Hot with drop_first=True:")
print(products_encoded_drop)
print("\n💡 Why drop_first?")
print("   • Avoids multicollinearity (columns perfectly predict each other)")
print("   • If Product_Phone=0 AND Product_Tablet=0, we KNOW it's Laptop")
print("   • Reduces dimensions without losing information")
# Out:
# ============================================================
#  ONE-HOT ENCODING (For Nominal Data)
# ============================================================
# 📊 Original Data:
#   Product  Price
# 0  Laptop   1000
# 1   Phone    800
# 2  Tablet    600
# 3  Laptop   1100
# 4   Phone    850
# 5   Watch    300
# 6  Tablet    650
#
# 📊 After One-Hot Encoding:
#    Price  Product_Laptop  Product_Phone  Product_Tablet  Product_Watch
# 0   1000            True          False           False          False
# 1    800           False           True           False          False
# 2    600           False          False            True          False
# 3   1100            True          False           False          False
# 4    850           False           True           False          False
# 5    300           False          False           False           True
# 6    650           False          False            True          False
#
# 💡 HOW IT WORKS:
#    • Creates a NEW COLUMN for each category
#    • Uses 1 if that's the category, 0 otherwise
#    • 'Laptop' becomes: Product_Laptop=1, Product_Phone=0, Product_Tablet=0
#
# ✓ ADVANTAGES:
#    • No false ordering (Laptop ≠ 'better' than Phone)
#    • ML algorithms treat each category independently
#
# ⚠️  DISADVANTAGES:
#    • Creates many columns if many categories
#    • Can lead to 'curse of dimensionality'
#
# 📊 One-Hot with drop_first=True:
#    Price  Product_Phone  Product_Tablet  Product_Watch
# 0   1000          False           False          False
# 1    800           True           False          False
# 2    600          False            True          False
# 3   1100          False           False          False
# 4    850           True           False          False
# 5    300          False           False           True
# 6    650          False            True          False
#
# 💡 Why drop_first?
#    • Avoids multicollinearity (columns perfectly predict each other)
#    • If Product_Phone=0 AND Product_Tablet=0, we KNOW it's Laptop
#    • Reduces dimensions without losing information
